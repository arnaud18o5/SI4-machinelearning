# %% [markdown]
# # TP regression
# 10/10/20

# %% [markdown]
# ## Practice 1
#
# ![image.png](attachment:image.png)

# %%
# import diabete dataset
from sklearn import datasets
diabetes = datasets.load_diabetes()
X = diabetes.data
y = diabetes.target

# %% [markdown]
# ### The dataset

# %%
print("Shape of data :",X.shape)
# Out:
# Shape of data : (442, 10)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=42)

# %%
from sklearn import linear_model
reg = linear_model.LinearRegression()
reg.fit(X_train, y_train)
print(reg.coef_)
# Out:
# [  18.08383103 -227.04654841  592.2754776   361.54657801 -655.89624143
#   353.71022539   14.40233952  142.86622578  594.01401521   31.67348554]

# %% [markdown]
# ### Scores

# %%
import numpy as np

print("Mean squared error:", np.mean((reg.predict(X_test) - y_test) ** 2))
print("Variance score:", reg.score(X_test, y_test))
# Out:
# Mean squared error: 2832.9913004407
# Variance score: 0.5157444756897698

# %% [markdown]
# The scores are not so good.

# %% [markdown]
# ## Practice 2
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Digits

# %%
digits = datasets.load_digits()
X = digits.data
y = digits.target

# %%
print("Shape of data :",X.shape)
# Out:
# Shape of data : (1797, 64)

# %%
# split data into train, test and validation sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.4, random_state=42)
X_test, X_val, y_test, y_val = train_test_split(X_test, y_test, test_size=.5, random_state=42)

# %% [markdown]
# ### Multiclass classification

# %% [markdown]
# #### OvR

# %%
# multiclass classification 
from matplotlib import pyplot as plt
from sklearn.linear_model import LogisticRegression
from sklearn import metrics

# multiclass classification
ovr = LogisticRegression(multi_class='ovr', max_iter=1000)
ovr.fit(X_train, y_train)
print("score", ovr.score(X_test, y_test))
# Out:
# score 0.9610027855153204

# %% [markdown]
# #### OvR

# %%
ovo = LogisticRegression(multi_class='multinomial', max_iter=3000)
ovo.fit(X_train, y_train)
print("score", ovo.score(X_test, y_test))
# Out:
# score 0.9665738161559888

# %% [markdown]
# ### Compare with decision tree
